# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Convolutional Architectures
# <a id=part3></a>

# %% [markdown]
# In this assignment we will explore convolution networks and the effects of their architecture on accuracy. We'll implement a common block-based deep CNN pattern and we'll perform various experiments on it while varying the architecture. Then we'll implement our own custom architecture to see whether we can get high classification results on CIFAR-10.

# %%
# !pip install tqdm==4.17.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.17.1
#   Downloading tqdm-4.17.1-py2.py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.0 MB/s
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.1
#     Uninstalling tqdm-4.64.1:
#       Successfully uninstalled tqdm-4.64.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.4.1 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.17.1 which is incompatible.
# prophet 1.1 requires tqdm>=4.36.1, but you have tqdm 4.17.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.17.1 which is incompatible.
# Successfully installed tqdm-4.17.1

# %%
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %%
from google.colab import drive
drive.mount('/content/drive') 
#change this
# %cd /content/drive/MyDrive/HomeWorks/HomeWork-DeepLearning/assignment2/CNN

from utils import *
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/HomeWorks/HomeWork-DeepLearning/assignment2/CNN

# %% [markdown]
# ## Convolutional layers and networks
# <a id=part3_1></a>

# %% [markdown]
# Convolutional layers are the most essential building blocks of the state of the art deep learning image classification models and also play an important role in many other tasks.
# As we already saw, convolutional layers operate on and produce volumes (3D tensors) of activations.
#
#
# One way to interpret convolutional layers is as a collection of 3D learnable filters,
# each of which operates on a small spatial region of the input volume.
# Each filter is convolved with the input volume ("slides over it"),
# and a dot product is computed at each location followed by a non-linearity which produces one activation.
# All these activations produce a 2D plane known as a **feature map**.
# Multiple feature maps (one for each filter) comprise the output volume.
#
# ![picture](https://sci2lab.github.io/ml_tutorial/images/cnn_convolution_3.png)
#
# A crucial property of convolutional layers is their translation invariance,
# i.e. their ability to detect features regardelss of their spatial location in the input.
#
# Convolutional network architectures usually follow a pattern basic repeating blocks: one or more convolution layers, each followed by a non-linearity (generally ReLU) and then a pooling layer to reduce spatial dimensions. Usually, the number of convolutional filters increases the deeper they are in the network.
# These layers are meant to extract features from the input.
# Then, one or more fully-connected layers is used to combine the extracted features into the required number of output class scores.

# %% [markdown]
# ## Building convolutional networks with PyTorch
# <a id=part3_2></a>

# %% [markdown]
# PyTorch provides all the basic building blocks needed for creating a convolutional arcitecture within the [`torch.nn`](https://pytorch.org/docs/stable/nn.html) package.
# Let's use them to create a basic convolutional network with the following architecture pattern:
#
#     [(CONV -> ReLU)*P -> MaxPool]*(N/P) -> (Linear -> ReLU)*M -> Linear
#
# Here $N$ is the total number of convolutional layers,
# $P$ specifies how many convolutions to perform before each pooling layer
# and $M$ specifies the number of hidden fully-connected layers before the final output layer.

# %% [markdown]
# **TODO**: Complete the implementaion of the `ConvClassifier` class in the `utils/models.py` module.

# %%
from  utils import models
torch.manual_seed(seed)

net = models.ConvClassifier((3,100,100), 10, filters=[32]*4, pool_every=2, hidden_dims=[100]*2).to(device)
print(net)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).to(device)
test_out = net(test_image.unsqueeze(0))
print('out =', test_out)

expected_out = torch.load('tests/assets/expected_conv_out.pt').to(device)
test.assertLess(torch.norm(test_out - expected_out).item(), 1e-5)
# Out:
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# out = tensor([[-0.0868, -0.3790, -0.4341, -0.1236, -0.2160,  0.1683,  0.4739,  0.0750,
#           0.1151, -0.1606]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Note about running on GPUs**.
#
# Notice how we called `.to(device)` on **both** the model and the input tensor.
# Here the `device` is a `torch.device` object that we created above. If an nvidia GPU is available on the machine you're running this on, the `device` will be `'cuda'`. When you run `.to(device)` on a model, it recursively goes over all the model parameter tensors and copies their memory to the GPU. Similarly, calling `.to(device)` on the input image also copies it.
#
# In order to train on a GPU, you need to make sure to move **all** your tensors to it. You'll get errors if you try to mix CPU and GPU tensors in a computation.

# %%
print(f'This notebook is running with device={device}')
print(f'The model parameter tensors are therefore also on device={next(net.parameters()).device}')
print(f'The test image is therefore also on device={test_image.device}')
# Out:
# This notebook is running with device=cuda
# The model parameter tensors are therefore also on device=cuda:0
# The test image is therefore also on device=cuda:0

# %% [markdown]
# Let's load CIFAR-10 again to use as our dataset.

# %%
data_dir = os.path.expanduser('~/.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')

x0,_ = ds_train[0]
in_size = x0.shape
num_classes = 10
print('input image size =', in_size)
# Out:
#   0%|          | 458752/170498071 [00:00<00:41, 4111940.07it/s]
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:01<00:00, 99896229.00it/s]
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples
# input image size = torch.Size([3, 32, 32])

# %% [markdown]
# Now as usual, as a sanity test let's make sure we can overfit a tiny dataset with our model. But first we need to adapt our `Trainer` for PyTorch models.

# %% [markdown]
# **TODO**: Complete the implementaion of the `TorchTrainer` class in the `utils/training.py` module.
# You should implement the funcitons:
# * fit (...)
# * train_batch(...)
# * test_batch(...)

# %%
import utils.training as training
torch.manual_seed(seed)

# Define a tiny part of the CIFAR-10 dataset to overfit it
batch_size = 2
max_batches = 25
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)

# Create model, loss and optimizer instances
model = models.ConvClassifier(in_size, num_classes, filters=[32], pool_every=1, hidden_dims=[100])
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9,)

# Use TorchTrainer to run only the training loop a few times.
trainer = training.TorchTrainer(model, loss_fn, optimizer, device)
best_acc = 0
for i in range(22):
    res = trainer.train_epoch(dl_train, max_batches=max_batches, verbose=(i%2==0))
    best_acc = res.accuracy if res.accuracy > best_acc else best_acc
    
# Test overfitting
test.assertGreaterEqual(best_acc, 95)
# Out:
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# train_batch (Avg. Loss 2.371, Accuracy 6.0): 100%|██████████| 25/25 [00:00<00:00, 255.35it/s]
# train_batch (Avg. Loss 2.238, Accuracy 16.0): 100%|██████████| 25/25 [00:00<00:00, 248.09it/s]
# train_batch (Avg. Loss 2.131, Accuracy 22.0): 100%|██████████| 25/25 [00:00<00:00, 250.33it/s]
# train_batch (Avg. Loss 1.830, Accuracy 36.0): 100%|██████████| 25/25 [00:00<00:00, 247.67it/s]
# train_batch (Avg. Loss 1.166, Accuracy 58.0): 100%|██████████| 25/25 [00:00<00:00, 222.09it/s]
# train_batch (Avg. Loss 1.213, Accuracy 56.0): 100%|██████████| 25/25 [00:00<00:00, 243.15it/s]
# train_batch (Avg. Loss 0.591, Accuracy 78.0): 100%|██████████| 25/25 [00:00<00:00, 229.32it/s]
# train_batch (Avg. Loss 0.423, Accuracy 82.0): 100%|██████████| 25/25 [00:00<00:00, 232.62it/s]
# train_batch (Avg. Loss 0.274, Accuracy 96.0): 100%|██████████| 25/25 [00:00<00:00, 228.14it/s]
# train_batch (Avg. Loss 0.026, Accuracy 100.0): 100%|██████████| 25/25 [00:00<00:00, 218.96it/s]
# train_batch (Avg. Loss 0.001, Accuracy 100.0): 100%|██████████| 25/25 [00:00<00:00, 212.96it/s]

# %% [markdown]
# ## Experimenting with model architectures
# <a id=part3_3></a>

# %% [markdown]
# You will now perform a series of experiments that train various model configurations on a much larger part of the CIFAR-10 dataset.
#
# To perform the experiments, you'll need to use a machine with a GPU since training time might be too long otherwise.

# %% [markdown]
# ### General notes for running experiments
#
# - It's important to give each experiment run a name as specified by the notebook instructions later on. The each run has a `run_name` parameter that will also be the name of the results file which this notebook will expect to load.
#
# - You will implement the code to run the experiments in the `utils/experiments.py` module.

# %% [markdown]
# ### Experiment 1 - Network depth and number of filters

# %% [markdown]
# In this part we will test some different architecture configurations based on our `ConvClassifier`.
# Specifically, we want to try different depths and number of features to see the effects these parameters have on the model's performance.
#
# To do this, we'll define two extra hyperparameters for our model, `K` (`filters_per_layer`) and `L` (`layers_per_block`).
# - `K` is a list, containing the number of filters we want to have in our conv layers.
# - `L` is the number of consecutive layers with the same number of filters to use.
#
# For example, if `K=[32, 64]` and `L=2` it means we want two conv layers with 32 filters followed by two conv layers with 64 filters. The feature-extraction part of our model will therefore be:
#
#     Conv(X,32)->ReLu->Conv(32,32)->ReLU->MaxPool->Conv(32,64)->ReLU->Conv(64,64)->ReLU->MaxPool
#
# We'll try various values of the `K` and `L` parameters in combination and see how each architecture trains.

# %% [markdown]
# First we need to write some code to run the experiment.
#
# **TODO**:
# 1. Implement the `run_experiment()` function in the `utils/experiments.py` module.
# 1. If you haven't done so already, it would be an excellent idea to implement the **early stopping** feature of the `Trainer` class.
#
# The following block tests that your implementation works. It's also meant to show you that each experiment run creates a result file containing the parameters to reproduce and the `FitResult` object for plotting.

# %%
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit

# Test experiment1 implementation on a few data samples and with a small model
experiments.run_experiment('test_run', seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                           filters_per_layer=[32], layers_per_block=1, pool_every=1, hidden_dims=[100])

# There should now be a file 'test_run.json' in your `results/` folder.
# We can use it to load the results of the experiment.
cfg, fit_res = load_experiment('results/test_run.json')
_, _ = plot_fit(fit_res)

# And `cfg` contains the exact parameters to reproduce it
print('experiment config: ', cfg)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.552, Accuracy 44.3): 100%|██████████| 850/850 [00:04<00:00, 188.99it/s]
# test_batch (Avg. Loss 1.321, Accuracy 53.9): 100%|██████████| 625/625 [00:02<00:00, 291.01it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.286, Accuracy 54.6): 100%|██████████| 850/850 [00:05<00:00, 169.29it/s]
# test_batch (Avg. Loss 1.270, Accuracy 54.9): 100%|██████████| 625/625 [00:02<00:00, 292.48it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.205, Accuracy 57.4): 100%|██████████| 850/850 [00:04<00:00, 171.85it/s]
# test_batch (Avg. Loss 1.175, Accuracy 58.0): 100%|██████████| 625/625 [00:02<00:00, 264.31it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.150, Accuracy 59.4): 100%|██████████| 850/850 [00:05<00:00, 146.76it/s]
# test_batch (Avg. Loss 1.149, Accuracy 59.4): 100%|██████████| 625/625 [00:02<00:00, 259.00it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.101, Accuracy 61.6): 100%|██████████| 850/850 [00:06<00:00, 140.31it/s]
# test_batch (Avg. Loss 1.125, Accuracy 59.8): 100%|██████████| 625/625 [00:02<00:00, 251.83it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.056, Accuracy 62.9): 100%|██████████| 850/850 [00:05<00:00, 156.19it/s]
# test_batch (Avg. Loss 1.089, Accuracy 61.2): 100%|██████████| 625/625 [00:02<00:00, 259.54it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.024, Accuracy 64.3): 100%|██████████| 850/850 [00:05<00:00, 147.06it/s]
# test_batch (Avg. Loss 1.098, Accuracy 60.5): 100%|██████████| 625/625 [00:02<00:00, 256.21it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.994, Accuracy 65.1): 100%|██████████| 850/850 [00:05<00:00, 149.50it/s]
# test_batch (Avg. Loss 1.052, Accuracy 62.2): 100%|██████████| 625/625 [00:02<00:00, 291.68it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.960, Accuracy 66.6): 100%|██████████| 850/850 [00:05<00:00, 143.54it/s]
# test_batch (Avg. Loss 1.042, Accuracy 62.6): 100%|██████████| 625/625 [00:02<00:00, 259.49it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.938, Accuracy 67.1): 100%|██████████| 850/850 [00:05<00:00, 166.76it/s]
# test_batch (Avg. Loss 1.059, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 289.30it/s]
# test_batch (Avg. Loss 1.070, Accuracy 62.6): 100%|██████████| 834/834 [00:04<00:00, 174.36it/s]
# ==================== Test Results ====================
# Test Accuracy: 62.61
# Test Accuracy: 1.070499756621371
# ======================================================
# *** Output file ./results/test_run.json written
# experiment config:  {'run_name': 'test_run', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'filters_per_layer': [32], 'layers_per_block': 1, 'pool_every': 1, 'hidden_dims': [100], 'ycn': False, 'kw': {}}

# %% [markdown]
# We'll use the following function to load multiple experiment results and plot them together.

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# #### Experiment 1.1: Varying the network depth (`L`)

# %% [markdown]
# First, we'll test the effect of the network depth on training.
#
# **Configuratons**:
# - `K=32` fixed, with `L=2,4,8,16` varying per run
# - `K=64` fixed, with `L=2,4,8,16` varying per run
#
# So 8 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_1_K{}_L{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_1_K32_L2`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit

# %%
for l in [2,4,8,16]:
    # Test experiment1 implementation on a few data samples and with a small model
    experiments.run_experiment(f'exp1_1_K32_L{l}',
                               seed=seed,
                               bs_train=50,
                               batches=10000,
                               epochs=30, 
                               early_stopping=5,
                               reg=2e-3,
                               lr=1e-3,
                               filters_per_layer=[32],
                               layers_per_block=l,
                               pool_every=4,
                               hidden_dims=[100, 100])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.573, Accuracy 42.6): 100%|██████████| 850/850 [00:06<00:00, 141.60it/s]
# test_batch (Avg. Loss 1.383, Accuracy 50.7): 100%|██████████| 625/625 [00:02<00:00, 253.49it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.339, Accuracy 51.7): 100%|██████████| 850/850 [00:07<00:00, 113.62it/s]
# test_batch (Avg. Loss 1.284, Accuracy 53.5): 100%|██████████| 625/625 [00:02<00:00, 234.00it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.237, Accuracy 55.7): 100%|██████████| 850/850 [00:07<00:00, 112.68it/s]
# test_batch (Avg. Loss 1.217, Accuracy 56.2): 100%|██████████| 625/625 [00:02<00:00, 254.05it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.167, Accuracy 58.2): 100%|██████████| 850/850 [00:07<00:00, 118.30it/s]
# test_batch (Avg. Loss 1.164, Accuracy 58.3): 100%|██████████| 625/625 [00:02<00:00, 243.58it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.101, Accuracy 60.6): 100%|██████████| 850/850 [00:07<00:00, 114.14it/s]
# test_batch (Avg. Loss 1.123, Accuracy 59.8): 100%|██████████| 625/625 [00:02<00:00, 239.01it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.045, Accuracy 62.9): 100%|██████████| 850/850 [00:07<00:00, 114.29it/s]
# test_batch (Avg. Loss 1.126, Accuracy 59.4): 100%|██████████| 625/625 [00:02<00:00, 256.59it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1
/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.595, Accuracy 78.9): 100%|██████████| 850/850 [00:07<00:00, 111.97it/s]
# test_batch (Avg. Loss 1.091, Accuracy 63.8): 100%|██████████| 625/625 [00:02<00:00, 228.83it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.578, Accuracy 79.7): 100%|██████████| 850/850 [00:07<00:00, 124.24it/s]
# test_batch (Avg. Loss 1.109, Accuracy 62.7): 100%|██████████| 625/625 [00:02<00:00, 264.28it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.557, Accuracy 80.3): 100%|██████████| 850/850 [00:06<00:00, 127.36it/s]
# test_batch (Avg. Loss 1.166, Accuracy 61.8): 100%|██████████| 625/625 [00:02<00:00, 268.51it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.545, Accuracy 80.9): 100%|██████████| 850/850 [00:06<00:00, 126.43it/s]
# test_batch (Avg. Loss 1.139, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 265.74it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.523, Accuracy 81.5): 100%|██████████| 850/850 [00:06<00:00, 128.73it/s]
# test_batch (Avg. Loss 1.157, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 268.20it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.507, Accuracy 82.2): 100%|██████████| 850/850 [00:06<00:00, 128.09it/s]
# test_batch (Avg. Loss 1.154, Accuracy 62.4): 100%|██████████| 625/625 [00:02<00:00, 263.57it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.493, Accuracy 82.5): 100%|██████████| 850/850 [00:07<00:00, 111.60it/s]
# test_batch (Avg. Loss 1.230, Accuracy 62.4): 100%|██████████| 625/625 [00:02<00:00, 236.47it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.483, Accuracy 83.2): 100%|██████████| 850/850 [00:07<00:00, 109.95it/s]
# test_batch (Avg. Loss 1.202, Accuracy 61.5): 100%|██████████| 625/625 [00:02<00:00, 244.26it/s]
# test_batch (Avg. Loss 1.224, Accuracy 61.3): 100%|██████████| 834/834 [00:05<00:00, 163.82it/s]
# ==================== Test Results ====================
# Test Accuracy: 61.26
# Test Accuracy: 1.2238074530907672
# ======================================================
# *** Output file ./results/exp1_1_K32_L2.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.718, Accuracy 36.5): 100%|██████████| 850/850 [00:08<00:00, 96.21it/s]
# test_batch (Avg. Loss 1.508, Accuracy 43.7): 100%|██████████| 625/625 [00:03<00:00, 202.49it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.435, Accuracy 47.8): 100%|██████████| 850/850 [00:07<00:00, 117.07it/s]
# test_batch (Avg. Loss 1.379, Accuracy 49.1): 100%|██████████| 625/625 [00:02<00:00, 260.69it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.277, Accuracy 54.0): 100%|██████████| 850/850 [00:07<00:00, 116.78it/s]
# test_batch (Avg. Loss 1.206, Accuracy 55.5): 100%|██████████| 625/625 [00:02<00:00, 247.92it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.170, Accuracy 58.3): 100%|██████████| 850/850 [00:07<00:00, 113.97it/s]
# test_batch (Avg. Loss 1.166, Accuracy 58.6): 100%|██████████| 625/625 [00:02<00:00, 243.09it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.099, Accuracy 60.7): 100%|██████████| 850/850 [00:07<00:00, 109.37it/s]
# test_batch (Avg. Loss 1.093, Accuracy 60.8): 100%|██████████| 625/625 [00:03<00:00, 205.17it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.043, Accuracy 63.0): 100%|██████████| 850/850 [00:08<00:00, 97.49it/s]
# test_batch (Avg. Loss 1.081, Accuracy 61.5): 100%|██████████| 625/625 [00:02<00:00, 208.70it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.004, Accuracy 64.3): 100%|██████████| 850/850 [00:07<00:00, 110.49it/s]
# test_batch (Avg. Loss 1.044, Accuracy 63.1): 100%|██████████| 625/625 [00:02<00:00, 216.81it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.956, Accuracy 65.8): 100%|██████████| 850/850 [00:08<00:00, 98.86it/s]
# test_batch (Avg. Loss 1.031, Accuracy 63.3): 100%|██████████| 625/625 [00:02<00:00, 213.50it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.918, Accuracy 67.3): 100%|██████████| 850/850 [00:08<00:00, 99.07it/s]
# test_batch (Avg. Loss 1.050, Accuracy 63.4): 100%|██████████| 625/625 [00:02<00:00, 249.65it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.880, Accuracy 68.6): 100%|██████████| 850/850 [00:07<00:00, 115.39it/s]
# test_batch (Avg. Loss 1.006, Accuracy 65.3): 100%|██████████| 625/625 [00:02<00:00, 257.55it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.850, Accuracy 69.9): 100%|██████████| 850/850 [00:07<00:00, 116.21it/s]
# test_batch (Avg. Loss 1.034, Accuracy 63.7): 100%|██████████| 625/625 [00:02<00:00, 256.91it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.816, Accuracy 70.9): 100%|██████████| 850/850 [00:07<00:00, 115.75it/s]
# test_batch (Avg. Loss 0.992, Accuracy 64.8): 100%|██████████| 625/625 [00:02<00:00, 246.01it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.788, Accuracy 72.1): 100%|██████████| 850/850 [00:07<00:00, 108.69it/s]
# test_batch (Avg. Loss 0.975, Accuracy 65.7): 100%|██████████| 625/625 [00:03<00:00, 207.40it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.761, Accuracy 73.1): 100%|██████████| 850/850 [00:08<00:00, 97.10it/s]
# test_batch (Avg. Loss 0.973, Accuracy 66.1): 100%|██████████| 625/625 [00:03<00:00, 202.88it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.738, Accuracy 73.9): 100%|██████████| 850/850 [00:08<00:00, 100.12it/s]
# test_batch (Avg. Loss 0.967, Accuracy 66.5): 100%|██████████| 625/625 [00:03<00:00, 205.51it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.721, Accuracy 74.6): 100%|██████████| 850/850 [00:08<00:00, 101.61it/s]
# test_batch (Avg. Loss 0.990, Accuracy 65.2): 100%|██████████| 625/625 [00:02<00:00, 226.91it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.692, Accuracy 75.5): 100%|██████████| 850/850 [00:08<00:00, 101.82it/s]
# test_batch (Avg. Loss 1.011, Accuracy 65.8): 100%|██████████| 625/625 [00:02<00:00, 241.06it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.677, Accuracy 75.9): 100%|██████████| 850/850 [00:07<00:00, 116.99it/s]
# test_batch (Avg. Loss 0.972, Accuracy 66.9): 100%|██████████| 625/625 [00:02<00:00, 245.70it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.657, Accuracy 76.6): 100%|██████████| 850/850 [00:07<00:00, 113.70it/s]
# test_batch (Avg. Loss 1.004, Accuracy 66.2): 100%|██████████| 625/625 [00:02<00:00, 261.38it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 0.634, Accuracy 77.6): 100%|██████████| 850/850 [00:07<00:00, 117.00it/s]
# test_batch (Avg. Loss 0.952, Accuracy 67.3): 100%|██████████| 625/625 [00:02<00:00, 211.26it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 0.615, Accuracy 78.1): 100%|██████████| 850/850 [00:09<00:00, 94.30it/s]
# test_batch (Avg. Loss 0.976, Accuracy 66.7): 100%|██████████| 625/625 [00:02<00:00, 217.74it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 0.597, Accuracy 78.7): 100%|██████████| 850/850 [00:08<00:00, 100.39it/s]
# test_batch (Avg. Loss 0.979, Accuracy 67.1): 100%|██████████| 625/625 [00:02<00:00, 247.60it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.580, Accuracy 79.5): 100%|██████████| 850/850 [00:08<00:00, 100.17it/s]
# test_batch (Avg. Loss 0.963, Accuracy 67.8): 100%|██████████| 625/625 [00:02<00:00, 218.31it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.568, Accuracy 79.9): 100%|██████████| 850/850 [00:08<00:00, 99.78it/s]
# test_batch (Avg. Loss 0.961, Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 216.43it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.552, Accuracy 80.4): 100%|██████████| 850/850 [00:07<00:00, 110.14it/s]
# test_batch (Avg. Loss 0.958, Accuracy 68.1): 100%|██████████| 625/625 [00:02<00:00, 233.28it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.534, Accuracy 81.1): 100%|██████████| 850/850 [00:07<00:00, 113.82it/s]
# test_batch (Avg. Loss 0.985, Accuracy 67.5): 100%|██████████| 625/625 [00:02<00:00, 245.32it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.522, Accuracy 81.2): 100%|██████████| 850/850 [00:07<00:00, 114.81it/s]
# test_batch (Avg. Loss 0.991, Accuracy 67.1): 100%|██████████| 625/625 [00:02<00:00, 237.69it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.506, Accuracy 82.1): 100%|██████████| 850/850 [00:08<00:00, 103.01it/s]
# test_batch (Avg. Loss 1.018, Accuracy 66.6): 100%|██████████| 625/625 [00:03<00:00, 203.88it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.492, Accuracy 82.5): 100%|██████████| 850/850 [00:08<00:00, 102.05it/s]
# test_batch (Avg. Loss 1.002, Accuracy 66.7): 100%|██████████| 625/625 [00:03<00:00, 206.49it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.480, Accuracy 83.0): 100%|██████████| 850/850 [00:07<00:00, 107.02it/s]
# test_batch (Avg. Loss 1.055, Accuracy 66.1): 100%|██████████| 625/625 [00:02<00:00, 215.71it/s]
# test_batch (Avg. Loss 1.030, Accuracy 67.2): 100%|██████████| 834/834 [00:06<00:00, 138.28it/s]
# ==================== Test Results ====================
# Test Accuracy: 67.19
# Test Accuracy: 1.0298478548779046
# ======================================================
# *** Output file ./results/exp1_1_K32_L4.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:09<00:00, 89.18it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:03<00:00, 201.27it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:09<00:00, 89.90it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 214.76it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 93.05it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 196.47it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:10<00:00, 78.54it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 181.39it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:10<00:00, 83.40it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 181.60it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:11<00:00, 76.84it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 178.53it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:10<00:00, 83.90it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 213.45it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 90.64it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 219.09it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:09<00:00, 91.14it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 187.84it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:11<00:00, 76.15it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 182.62it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:10<00:00, 80.69it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 182.94it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:10<00:00, 77.96it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 187.41it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 93.62it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 210.78it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:05<00:00, 146.31it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026262550331134
# ======================================================
# *** Output file ./results/exp1_1_K32_L8.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (18): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU()
#     (20): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU()
#     (22): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU()
#     (24): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): ReLU()
#     (29): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): ReLU()
#     (31): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (32): ReLU()
#     (33): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): ReLU()
#     (35): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:13<00:00, 62.11it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:04<00:00, 144.65it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 57.81it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 164.38it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:15<00:00, 54.77it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 161.89it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 850/850 [00:12<00:00, 65.86it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 182.02it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:12<00:00, 65.86it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 179.47it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:15<00:00, 56.13it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:04<00:00, 144.62it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:15<00:00, 53.64it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:04<00:00, 148.31it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 58.82it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 169.76it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 133.48it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026405735839184
# ======================================================
# *** Output file ./results/exp1_1_K32_L16.json written

# %%
plot_exp_results('exp1_1_K32*.json')
# Out:
# common config:  {'run_name': 'exp1_1_K32_L8', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
for l in [2,4,8,16]:
    # Test experiment1 implementation on a few data samples and with a small model
    experiments.run_experiment(f'exp1_1_K64_L{l}',
                               seed=seed,
                               bs_train=50,
                               batches=10000,
                               epochs=30, 
                               early_stopping=5,
                               reg=2e-3,
                               lr=1e-3,
                               filters_per_layer=[64],
                               layers_per_block=l,
                               pool_every=4,
                               hidden_dims=[100, 100])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=65536, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.549, Accuracy 43.6): 100%|██████████| 850/850 [00:10<00:00, 84.69it/s]
# test_batch (Avg. Loss 1.348, Accuracy 51.0): 100%|██████████| 625/625 [00:02<00:00, 240.25it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.294, Accuracy 53.5): 100%|██████████| 850/850 [00:10<00:00, 83.96it/s]
# test_batch (Avg. Loss 1.206, Accuracy 56.4): 100%|██████████| 625/625 [00:02<00:00, 253.80it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.169, Accuracy 58.3): 100%|██████████| 850/850 [00:09<00:00, 87.40it/s]
# test_batch (Avg. Loss 1.172, Accuracy 57.7): 100%|██████████| 625/625 [00:02<00:00, 252.05it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.086, Accuracy 61.1): 100%|██████████| 850/850 [00:09<00:00, 87.63it/s]
# test_batch (Avg. Loss 1.126, Accuracy 58.7): 100%|██████████| 625/625 [00:02<00:00, 280.44it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.020, Accuracy 64.0): 100%|██████████| 850/850 [00:09<00:00, 92.10it/s]
# test_batch (Avg. Loss 1.086, Accuracy 60.8): 100%|██████████| 625/625 [00:02<00:00, 262.57it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.973, Accuracy 65.4): 100%|██████████| 850/850 [00:09<00:00, 92.20it/s]
# test_batch (Avg. Loss 1.106, Accuracy 59.7): 100%|██████████| 625/625 [00:02<00:00, 268.61it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.928, Accuracy 67.2): 100%|██████████| 850/850 [00:09<00:00, 85.68it/s]
# test_batch (Avg. Loss 1.044, Accuracy 63.3): 100%|██████████| 625/625 [00:02<00:00, 249.14it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.889, Accuracy 68.5): 100%|██████████| 850/850 [00:09<00:00, 85.50it/s]
# test_batch (Avg. Loss 1.013, Accuracy 63.1): 100%|██████████| 625/625 [00:02<00:00, 244.25it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.856, Accuracy 69.5): 100%|██████████| 850/850 [00:09<00:00, 86.15it/s]
# test_batch (Avg. Loss 1.048, Accuracy 62.6): 100%|██████████| 625/625 [00:02<00:00, 260.41it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.827, Accuracy 70.8): 100%|██████████| 850/850 [00:10<00:00, 84.16it/s]
# test_batch (Avg. Loss 1.004, Accuracy 64.8): 100%|██████████| 625/625 [00:02<00:00, 221.80it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.792, Accuracy 71.9): 100%|██████████| 850/850 [00:09<00:00, 90.25it/s]
# test_batch (Avg. Loss 1.016, Accuracy 63.7): 100%|██████████| 625/625 [00:02<00:00, 276.77it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.768, Accuracy 73.0): 100%|██████████| 850/850 [00:09<00:00, 92.14it/s]
# test_batch (Avg. Loss 1.020, Accuracy 63.9): 100%|██████████| 625/625 [00:02<00:00, 252.77it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.740, Accuracy 73.8): 100%|██████████| 850/850 [00:09<00:00, 91.51it/s]
# test_batch (Avg. Loss 1.031, Accuracy 64.4): 100%|██████████| 625/625 [00:02<00:00, 256.54it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.714, Accuracy 74.9): 100%|██████████| 850/850 [00:09<00:00, 89.11it/s]
# test_batch (Avg. Loss 1.051, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 257.96it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.689, Accuracy 75.6): 100%|██████████| 850/850 [00:09<00:00, 85.05it/s]
# test_batch (Avg. Loss 1.058, Accuracy 63.1): 100%|██████████| 625/625 [00:02<00:00, 240.34it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.664, Accuracy 76.6): 100%|██████████| 850/850 [00:10<00:00, 83.85it/s]
# test_batch (Avg. Loss 1.063, Accuracy 64.0): 100%|██████████| 625/625 [00:02<00:00, 233.72it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.642, Accuracy 77.2): 100%|██████████| 850/850 [00:09<00:00, 86.71it/s]
# test_batch (Avg. Loss 1.054, Accuracy 63.1): 100%|██████████| 625/625 [00:02<00:00, 239.48it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.610, Accuracy 78.4): 100%|██████████| 850/850 [00:10<00:00, 83.71it/s]
# test_batch (Avg. Loss 1.084, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 273.11it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.584, Accuracy 79.3): 100%|██████████| 850/850 [00:09<00:00, 91.33it/s]
# test_batch (Avg. Loss 1.096, Accuracy 64.0): 100%|██████████| 625/625 [00:02<00:00, 276.96it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 0.559, Accuracy 80.2): 100%|██████████| 850/850 [00:09<00:00, 90.44it/s]
# test_batch (Avg. Loss 1.140, Accuracy 63.3): 100%|██████████| 625/625 [00:02<00:00, 273.74it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 0.539, Accuracy 81.0): 100%|██████████| 850/850 [00:09<00:00, 88.44it/s]
# test_batch (Avg. Loss 1.094, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 231.75it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 0.516, Accuracy 81.7): 100%|██████████| 850/850 [00:10<00:00, 84.81it/s]
# test_batch (Avg. Loss 1.123, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 235.37it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.504, Accuracy 82.2): 100%|██████████| 850/850 [00:10<00:00, 84.69it/s]
# test_batch (Avg. Loss 1.155, Accuracy 63.0): 100%|██████████| 625/625 [00:02<00:00, 233.83it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.484, Accuracy 82.9): 100%|██████████| 850/850 [00:09<00:00, 87.84it/s]
# test_batch (Avg. Loss 1.205, Accuracy 61.3): 100%|██████████| 625/625 [00:02<00:00, 223.10it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.469, Accuracy 83.5): 100%|██████████| 850/850 [00:09<00:00, 87.71it/s]
# test_batch (Avg. Loss 1.190, Accuracy 63.2): 100%|██████████| 625/625 [00:02<00:00, 251.60it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.447, Accuracy 84.4): 100%|██████████| 850/850 [00:09<00:00, 91.04it/s]
# test_batch (Avg. Loss 1.191, Accuracy 63.2): 100%|██████████| 625/625 [00:02<00:00, 253.42it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.438, Accuracy 84.7): 100%|██████████| 850/850 [00:09<00:00, 90.90it/s]
# test_batch (Avg. Loss 1.206, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 261.63it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.433, Accuracy 84.8): 100%|██████████| 850/850 [00:09<00:00, 91.50it/s]
# test_batch (Avg. Loss 1.211, Accuracy 62.3): 100%|██████████| 625/625 [00:02<00:00, 224.52it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.420, Accuracy 85.1): 100%|██████████| 850/850 [00:10<00:00, 83.90it/s]
# test_batch (Avg. Loss 1.257, Accuracy 61.2): 100%|██████████| 625/625 [00:02<00:00, 247.97it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.410, Accuracy 85.8): 100%|██████████| 850/850 [00:10<00:00, 84.32it/s]
# test_batch (Avg. Loss 1.242, Accuracy 61.7): 100%|██████████| 625/625 [00:02<00:00, 227.89it/s]
# test_batch (Avg. Loss 1.241, Accuracy 62.5): 100%|██████████| 834/834 [00:06<00:00, 135.25it/s]
# ==================== Test Results ====================
# Test Accuracy: 62.5
# Test Accuracy: 1.2413881079604228
# ======================================================
# *** Output file ./results/exp1_1_K64_L2.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.736, Accuracy 35.8): 100%|██████████| 850/850 [00:12<00:00, 71.25it/s]
# test_batch (Avg. Loss 1.518, Accuracy 43.7): 100%|██████████| 625/625 [00:02<00:00, 232.63it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1
/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:15<00:00, 56.38it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 184.28it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 58.41it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 218.03it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:14<00:00, 58.49it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 211.99it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:15<00:00, 55.02it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 190.62it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:15<00:00, 55.69it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 190.83it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:14<00:00, 58.65it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:02<00:00, 223.28it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:14<00:00, 58.97it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 198.93it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:14<00:00, 59.63it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 219.63it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 126.81it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026289459612728
# ======================================================
# *** Output file ./results/exp1_1_K64_L8.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU()
#     (20): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU()
#     (22): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU()
#     (24): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): ReLU()
#     (29): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): ReLU()
#     (31): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (32): ReLU()
#     (33): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): ReLU()
#     (35): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:18<00:00, 48.96it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 160.20it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:17<00:00, 49.14it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 170.57it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 50.95it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 169.71it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:16<00:00, 51.27it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:04<00:00, 146.52it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:17<00:00, 48.05it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:04<00:00, 149.04it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:17<00:00, 48.96it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:04<00:00, 152.41it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 50.59it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 170.86it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 123.27it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026134650484265
# ======================================================
# *** Output file ./results/exp1_1_K64_L16.json written

# %%
plot_exp_results('exp1_1_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_1_K64_L8', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %% [markdown]
# ### Question 1
#
# Analyze your results from experiment 1.1. In particular,
# 1.  Explain the effect of depth on the accuracy. What depth produces the best results and why do you think that's the case?
# 2. Were there values of `L` for which the network wasn't trainable? what causes this? Suggest two things which may be done to resolve it at least partially.

# %% [markdown]
# **ANSWER**:
# 1. At the training accuracy graph we can see the getting better after each epoch (for l_2 and l_4, for l_8 and l_16 the accuracy doesnt improve). As for the test accuracy we can see that for the first 10 epochs the accuracy for L_2 and L_4 is improving, after wards its stays more of the same, where as the accuracy for L_8 and L_8 doesnt not improve and stays the same.
# As shown in the graph, The best accuracy results coming from the depths 2 and 4.
# for the training result we can see that between depth 2 and depth 4 there isnt much any different, but at the test result we can see that depth 4 is more accurate. In contrast, we can see that depth 8 and depth 16 shows poor results (are untrainable).
# The cause for the poor results in depth 8 and 16 may be because the depth is too much and causing exploding gradient/vanishing gradient.
# We think depth 4 produces better results than depth 2 because there are more layers for the CNN to work with, which as taught in class, results in better performance.
#
# 2. The values of L which were not trainable are L_8 and L_16.
# What may cause them to not be trainable is fact that they are too deep, which may cause exploding gradient/vanishing gradient.
# We can resolve the problem partially with the following 2 steps:
#
# 1) We can normilaize the batches, which will improve perfomance
#
# 2) For exploding gradient we can use the clipping gradient method, which will partially help in this case.

# %% [markdown]
# #### Experiment 1.2: Varying the number of filters per layer (`K`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `L=2` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=4` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=8` fixed, with `K=[32],[64],[128],[256]` varying per run.
#
# So 12 different runs in total. To clarify, each run `K` takes the value of a list with a single element.
#
# **Naming runs**:
# Each run should be named `exp1_2_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_2_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
for l in [2,4,8]:
    for k in [32,64,128,256]:
        # Test experiment1 implementation on a few data samples and with a small model
        experiments.run_experiment(f'exp1_2_L{l}_K{k}',
                                   seed=seed,
                                   bs_train=50,
                                   batches=10000,
                                   epochs=30, 
                                   early_stopping=5,
                                   reg=2e-3,
                                   lr=1e-3,
                                   filters_per_layer=[k],
                                   layers_per_block=l,
                                   pool_every=4, 
                                   hidden_dims=[100, 100])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.571, Accuracy 42.7): 100%|██████████| 850/850 [00:07<00:00, 120.48it/s]
# test_batch (Avg. Loss 1.396, Accuracy 50.3): 100%|██████████| 625/625 [00:02<00:00, 240.85it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.340, Accuracy 51.8): 100%|██████████| 850/850 [00:07<00:00, 112.02it/s]
# test_batch (Avg. Loss 1.340, Accuracy 51.1): 100%|██████████| 625/625 [00:02<00:00, 247.56it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.240, Accuracy 55.4): 100%|██████████| 850/850 [00:07<00:00, 113.06it/s]
# test_batch (Avg. Loss 1.204, Accuracy 56.5): 100%|██████████| 625/625 [00:02<00:00, 238.78it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.169, Accuracy 58.2): 100%|██████████| 850/850 [00:07<00:00, 114.57it/s]
# test_batch (Avg. Loss 1.170, Accuracy 58.2): 100%|██████████| 625/625 [00:02<00:00, 245.01it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.102, Accuracy 60.7): 100%|██████████| 850/850 [00:06<00:00, 124.06it/s]
# test_batch (Avg. Loss 1.137, Accuracy 59.1): 100%|██████████| 625/625 [00:02<00:00, 240.89it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.049, Accuracy 62.9): 100%|██████████| 850/850 [00:06<00:00, 127.77it/s]
# test_batch (Avg. Loss 1.122, Accuracy 60.2): 100%|██████████| 625/625 [00:02<00:00, 266.25it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.012, Accuracy 64.2): 100%|██████████| 850/850 [00:06<00:00, 134.00it/s]
# test_batch (Avg. Loss 1.083, Accuracy 60.1): 100%|██████████| 625/625 [00:02<00:00, 280.27it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.971, Accuracy 65.8): 100%|██████████| 850/850 [00:06<00:00, 130.84it/s]
# test_batch (Avg. Loss 1.072, Accuracy 61.6): 100%|██████████| 625/625 [00:02<00:00, 284.85it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.932, Accuracy 67.1): 100%|██████████| 850/850 [00:07<00:00, 117.80it/s]
# test_batch (Avg. Loss 1.065, Accuracy 62.3): 100%|██████████| 625/625 [00:02<00:00, 237.92it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.896, Accuracy 68.4): 100%|██████████| 850/850 [00:07<00:00, 108.59it/s]
# test_batch (Avg. Loss 1.017, Accuracy 64.0): 100%|██████████| 625/625 [00:02<00:00, 244.22it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.865, Accuracy 69.5): 100%|██████████| 850/850 [00:08<00:00, 105.63it/s]
# test_batch (Avg. Loss 1.078, Accuracy 61.9): 100%|██████████| 625/625 [00:02<00:00, 231.66it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.836, Accuracy 70.6): 100%|██████████| 850/850 [00:07<00:00, 118.63it/s]
# test_batch (Avg. Loss 1.049, Accuracy 62.4): 100%|██████████| 625/625 [00:02<00:00, 243.47it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.814, Accuracy 71.1): 100%|██████████| 850/850 [00:07<00:00, 119.20it/s]
# test_batch (Avg. Loss 1.040, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 237.28it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.790, Accuracy 72.2): 100%|██████████| 850/850 [00:06<00:00, 127.53it/s]
# test_batch (Avg. Loss 1.013, Accuracy 64.7): 100%|██████████| 625/625 [00:02<00:00, 268.38it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0
Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 251.04it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.499, Accuracy 82.2): 100%|██████████| 850/850 [00:07<00:00, 112.89it/s]
# test_batch (Avg. Loss 1.070, Accuracy 65.6): 100%|██████████| 625/625 [00:02<00:00, 258.74it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.487, Accuracy 82.6): 100%|██████████| 850/850 [00:07<00:00, 106.34it/s]
# test_batch (Avg. Loss 1.047, Accuracy 67.5): 100%|██████████| 625/625 [00:02<00:00, 217.61it/s]
# test_batch (Avg. Loss 1.070, Accuracy 67.1): 100%|██████████| 834/834 [00:05<00:00, 148.84it/s]
# ==================== Test Results ====================
# Test Accuracy: 67.06
# Test Accuracy: 1.0702386933023766
# ======================================================
# *** Output file ./results/exp1_2_L4_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.747, Accuracy 35.6): 100%|██████████| 850/850 [00:13<00:00, 65.13it/s]
# test_batch (Avg. Loss 1.539, Accuracy 43.4): 100%|██████████| 625/625 [00:02<00:00, 219.84it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.435, Accuracy 47.8): 100%|██████████| 850/850 [00:13<00:00, 64.95it/s]
# test_batch (Avg. Loss 1.327, Accuracy 51.2): 100%|██████████| 625/625 [00:02<00:00, 222.39it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.268, Accuracy 54.3): 100%|██████████| 850/850 [00:12<00:00, 67.06it/s]
# test_batch (Avg. Loss 1.244, Accuracy 55.3): 100%|██████████| 625/625 [00:02<00:00, 254.27it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.150, Accuracy 58.8): 100%|██████████| 850/850 [00:12<00:00, 68.95it/s]
# test_batch (Avg. Loss 1.134, Accuracy 59.7): 100%|██████████| 625/625 [00:02<00:00, 250.16it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.059, Accuracy 62.3): 100%|██████████| 850/850 [00:12<00:00, 67.43it/s]
# test_batch (Avg. Loss 1.119, Accuracy 60.0): 100%|██████████| 625/625 [00:02<00:00, 215.82it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.985, Accuracy 65.2): 100%|██████████| 850/850 [00:12<00:00, 66.24it/s]
# test_batch (Avg. Loss 1.062, Accuracy 61.8): 100%|██████████| 625/625 [00:02<00:00, 224.84it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.929, Accuracy 67.2): 100%|██████████| 850/850 [00:13<00:00, 65.29it/s]
# test_batch (Avg. Loss 1.012, Accuracy 64.3): 100%|██████████| 625/625 [00:02<00:00, 225.76it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.878, Accuracy 68.9): 100%|██████████| 850/850 [00:13<00:00, 64.87it/s]
# test_batch (Avg. Loss 1.006, Accuracy 64.4): 100%|██████████| 625/625 [00:02<00:00, 251.50it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.844, Accuracy 70.3): 100%|██████████| 850/850 [00:12<00:00, 68.58it/s]
# test_batch (Avg. Loss 0.935, Accuracy 67.2): 100%|██████████| 625/625 [00:02<00:00, 245.32it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.797, Accuracy 72.1): 100%|██████████| 850/850 [00:12<00:00, 67.25it/s]
# test_batch (Avg. Loss 0.973, Accuracy 65.6): 100%|██████████| 625/625 [00:02<00:00, 227.08it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.781, Accuracy 72.5): 100%|██████████| 850/850 [00:12<00:00, 66.17it/s]
# test_batch (Avg. Loss 0.945, Accuracy 66.8): 100%|██████████| 625/625 [00:02<00:00, 213.05it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.736, Accuracy 73.9): 100%|██████████| 850/850 [00:13<00:00, 64.36it/s]
# test_batch (Avg. Loss 1.005, Accuracy 65.5): 100%|██████████| 625/625 [00:02<00:00, 223.24it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.714, Accuracy 74.6): 100%|██████████| 850/850 [00:13<00:00, 65.20it/s]
# test_batch (Avg. Loss 0.930, Accuracy 67.7): 100%|██████████| 625/625 [00:02<00:00, 225.43it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.681, Accuracy 76.2): 100%|██████████| 850/850 [00:12<00:00, 68.66it/s]
# test_batch (Avg. Loss 0.959, Accuracy 67.1): 100%|██████████| 625/625 [00:02<00:00, 258.38it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.654, Accuracy 76.8): 100%|██████████| 850/850 [00:12<00:00, 68.65it/s]
# test_batch (Avg. Loss 0.960, Accuracy 66.8): 100%|██████████| 625/625 [00:02<00:00, 247.30it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.636, Accuracy 77.6): 100%|██████████| 850/850 [00:12<00:00, 68.70it/s]
# test_batch (Avg. Loss 0.984, Accuracy 67.5): 100%|██████████| 625/625 [00:02<00:00, 249.99it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.610, Accuracy 78.4): 100%|██████████| 850/850 [00:13<00:00, 63.60it/s]
# test_batch (Avg. Loss 0.964, Accuracy 67.3): 100%|██████████| 625/625 [00:02<00:00, 231.59it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.586, Accuracy 79.4): 100%|██████████| 850/850 [00:13<00:00, 64.34it/s]
# test_batch (Avg. Loss 0.967, Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 222.25it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.557, Accuracy 80.2): 100%|██████████| 850/850 [00:13<00:00, 64.13it/s]
# test_batch (Avg. Loss 0.967, Accuracy 67.3): 100%|██████████| 625/625 [00:02<00:00, 223.62it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 0.540, Accuracy 80.8): 100%|██████████| 850/850 [00:12<00:00, 69.36it/s]
# test_batch (Avg. Loss 0.956, Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 249.47it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 0.523, Accuracy 81.3): 100%|██████████| 850/850 [00:12<00:00, 70.04it/s]
# test_batch (Avg. Loss 0.990, Accuracy 67.8): 100%|██████████| 625/625 [00:02<00:00, 250.55it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 0.508, Accuracy 81.9): 100%|██████████| 850/850 [00:12<00:00, 65.58it/s]
# test_batch (Avg. Loss 1.014, Accuracy 67.2): 100%|██████████| 625/625 [00:02<00:00, 229.81it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.487, Accuracy 82.6): 100%|██████████| 850/850 [00:12<00:00, 62.68it/s]
# test_batch (Avg. Loss 1.053, Accuracy 66.6): 100%|██████████| 625/625 [00:02<00:00, 223.09it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.471, Accuracy 83.3): 100%|██████████| 850/850 [00:13<00:00, 64.45it/s]
# test_batch (Avg. Loss 1.053, Accuracy 66.6): 100%|██████████| 625/625 [00:02<00:00, 226.63it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.453, Accuracy 83.8): 100%|██████████| 850/850 [00:13<00:00, 64.88it/s]
# test_batch (Avg. Loss 1.082, Accuracy 66.6): 100%|██████████| 625/625 [00:02<00:00, 245.17it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.440, Accuracy 84.4): 100%|██████████| 850/850 [00:12<00:00, 68.75it/s]
# test_batch (Avg. Loss 1.126, Accuracy 65.7): 100%|██████████| 625/625 [00:02<00:00, 242.13it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.427, Accuracy 84.8): 100%|██████████| 850/850 [00:12<00:00, 68.90it/s]
# test_batch (Avg. Loss 1.121, Accuracy 66.5): 100%|██████████| 625/625 [00:02<00:00, 250.56it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.418, Accuracy 85.1): 100%|██████████| 850/850 [00:12<00:00, 66.11it/s]
# test_batch (Avg. Loss 1.089, Accuracy 66.0): 100%|██████████| 625/625 [00:02<00:00, 231.96it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.406, Accuracy 85.5): 100%|██████████| 850/850 [00:12<00:00, 66.24it/s]
# test_batch (Avg. Loss 1.127, Accuracy 65.4): 100%|██████████| 625/625 [00:02<00:00, 228.72it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.398, Accuracy 85.8): 100%|██████████| 850/850 [00:13<00:00, 63.91it/s]
# test_batch (Avg. Loss 1.187, Accuracy 66.0): 100%|██████████| 625/625 [00:02<00:00, 222.13it/s]
# test_batch (Avg. Loss 1.194, Accuracy 65.8): 100%|██████████| 834/834 [00:06<00:00, 122.89it/s]
# ==================== Test Results ====================
# Test Accuracy: 65.78
# Test Accuracy: 1.19381016866266
# ======================================================
# *** Output file ./results/exp1_2_L4_K64.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.710, Accuracy 37.0): 100%|██████████| 850/850 [00:22<00:00, 37.89it/s]
# test_batch (Avg. Loss 1.457, Accuracy 46.8): 100%|██████████| 625/625 [00:02<00:00, 209.72it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.352, Accuracy 50.8): 100%|██████████| 850/850 [00:23<00:00, 36.72it/s]
# test_batch (Avg. Loss 1.249, Accuracy 55.2): 100%|██████████| 625/625 [00:03<00:00, 182.04it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.146, Accuracy 59.1): 100%|██████████| 850/850 [00:23<00:00, 36.87it/s]
# test_batch (Avg. Loss 1.128, Accuracy 59.6): 100%|██████████| 625/625 [00:03<00:00, 187.22it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.006, Accuracy 64.1): 100%|██████████| 850/850 [00:22<00:00, 38.02it/s]
# test_batch (Avg. Loss 1.006, Accuracy 63.9): 100%|██████████| 625/625 [00:03<00:00, 206.05it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.905, Accuracy 67.9): 100%|██████████| 850/850 [00:22<00:00, 37.43it/s]
# test_batch (Avg. Loss 0.978, Accuracy 66.2): 100%|██████████| 625/625 [00:03<00:00, 188.58it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.840, Accuracy 70.3): 100%|██████████| 850/850 [00:23<00:00, 36.83it/s]
# test_batch (Avg. Loss 0.915, Accuracy 67.5): 100%|██████████| 625/625 [00:03<00:00, 189.55it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.774, Accuracy 72.5): 100%|██████████| 850/850 [00:22<00:00, 37.43it/s]
# test_batch (Avg. Loss 0.921, Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 211.25it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.742, Accuracy 73.6): 100%|██████████| 850/850 [00:22<00:00, 37.78it/s]
# test_batch (Avg. Loss 0.945, Accuracy 66.4): 100%|██████████| 625/625 [00:03<00:00, 194.50it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.697, Accuracy 75.4): 100%|██████████| 850/850 [00:22<00:00, 37.06it/s]
# test_batch (Avg. Loss 0.932, Accuracy 67.2): 100%|██████████| 625/625 [00:03<00:00, 193.58it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.672, Accuracy 76.4): 100%|██████████| 850/850 [00:23<00:00, 36.80it/s]
# test_batch (Avg. Loss 0.908, Accuracy 68.2): 100%|██████████| 625/625 [00:03<00:00, 199.89it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.626, Accuracy 77.9): 100%|██████████| 850/850 [00:22<00:00, 37.96it/s]
# test_batch (Avg. Loss 0.899, Accuracy 69.0): 100%|██████████| 625/625 [00:03<00:00, 201.70it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.603, Accuracy 78.6): 100%|██████████| 850/850 [00:22<00:00, 37.12it/s]
# test_batch (Avg. Loss 0.953, Accuracy 67.8): 100%|██████████| 625/625 [00:03<00:00, 192.05it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.569, Accuracy 79.7): 100%|██████████| 850/850 [00:23<00:00, 36.70it/s]
# test_batch (Avg. Loss 0.935, Accuracy 68.5): 100%|██████████| 625/625 [00:03<00:00, 192.72it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.547, Accuracy 80.7): 100%|██████████| 850/850 [00:22<00:00, 37.95it/s]
# test_batch (Avg. Loss 0.966, Accuracy 68.6): 100%|██████████| 625/625 [00:03<00:00, 201.54it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.517, Accuracy 81.5): 100%|██████████| 850/850 [00:22<00:00, 37.46it/s]
# ...
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.414, Accuracy 85.3): 100%|██████████| 850/850 [00:56<00:00, 14.96it/s]
# test_batch (Avg. Loss 0.943, Accuracy 69.7): 100%|██████████| 625/625 [00:04<00:00, 125.07it/s]
# --- EPOCH 24/30 ---
# train_batch (Avg. Loss 0.399, Accuracy 85.9): 100%|██████████| 850/850 [00:56<00:00, 15.01it/s]
# test_batch (Avg. Loss 1.030, Accuracy 69.2): 100%|██████████| 625/625 [00:04<00:00, 125.23it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.387, Accuracy 86.2): 100%|██████████| 850/850 [00:56<00:00, 15.05it/s]
# test_batch (Avg. Loss 1.047, Accuracy 68.1): 100%|██████████| 625/625 [00:04<00:00, 127.96it/s]
# --- EPOCH 26/30 ---
# train_batch (Avg. Loss 0.373, Accuracy 86.8): 100%|██████████| 850/850 [00:56<00:00, 14.98it/s]
# test_batch (Avg. Loss 1.009, Accuracy 69.3): 100%|██████████| 625/625 [00:04<00:00, 126.33it/s]
# --- EPOCH 27/30 ---
# train_batch (Avg. Loss 0.360, Accuracy 87.2): 100%|██████████| 850/850 [00:56<00:00, 15.23it/s]
# test_batch (Avg. Loss 1.010, Accuracy 69.2): 100%|██████████| 625/625 [00:04<00:00, 126.00it/s]
# --- EPOCH 28/30 ---
# train_batch (Avg. Loss 0.348, Accuracy 87.7): 100%|██████████| 850/850 [00:56<00:00, 15.15it/s]
# test_batch (Avg. Loss 1.062, Accuracy 68.3): 100%|██████████| 625/625 [00:04<00:00, 127.89it/s]
# --- EPOCH 29/30 ---
# train_batch (Avg. Loss 0.346, Accuracy 87.6): 100%|██████████| 850/850 [00:56<00:00, 15.15it/s]
# test_batch (Avg. Loss 1.044, Accuracy 68.8): 100%|██████████| 625/625 [00:04<00:00, 125.49it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.329, Accuracy 88.3): 100%|██████████| 850/850 [00:56<00:00, 15.10it/s]
# test_batch (Avg. Loss 1.048, Accuracy 68.5): 100%|██████████| 625/625 [00:04<00:00, 127.68it/s]
# test_batch (Avg. Loss 1.056, Accuracy 68.5): 100%|██████████| 834/834 [00:08<00:00, 97.95it/s]
# ==================== Test Results ====================
# Test Accuracy: 68.46
# Test Accuracy: 1.055899246964309
# ======================================================
# *** Output file ./results/exp1_2_L4_K256.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:09<00:00, 93.32it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:02<00:00, 229.38it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:09<00:00, 87.82it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 238.00it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 88.69it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 233.96it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 88.65it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 232.24it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:09<00:00, 87.03it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 223.44it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:09<00:00, 88.34it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 235.22it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:09<00:00, 92.11it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 231.19it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:09<00:00, 88.40it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 227.28it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:10<00:00, 84.95it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:02<00:00, 229.01it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:05<00:00, 141.87it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026360636420673
# ======================================================
# *** Output file ./results/exp1_2_L8_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:14<00:00, 58.81it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.5): 100%|██████████| 625/625 [00:02<00:00, 225.28it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 58.53it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:02<00:00, 225.44it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 58.54it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 235.04it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:14<00:00, 57.75it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 235.10it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:14<00:00, 58.68it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:02<00:00, 237.60it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:14<00:00, 58.77it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:02<00:00, 231.79it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:14<00:00, 58.61it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:02<00:00, 238.40it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:14<00:00, 60.06it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 235.64it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:14<00:00, 58.60it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 240.88it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:05<00:00, 154.04it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026418437203056
# ======================================================
# *** Output file ./results/exp1_2_L8_K64.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:32<00:00, 26.52it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 195.59it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:31<00:00, 26.75it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 191.25it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:31<00:00, 26.57it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 194.06it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:32<00:00, 26.36it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 188.66it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:32<00:00, 26.37it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 191.53it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:32<00:00, 25.95it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 194.10it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:33<00:00, 25.63it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 192.69it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:33<00:00, 25.62it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 186.26it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:33<00:00, 25.67it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 197.02it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:33<00:00, 25.69it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 194.36it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 127.96it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3026251798625186
# ======================================================
# *** Output file ./results/exp1_2_L8_K128.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [01:11<00:00, 12.33it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:06<00:00, 102.77it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [01:09<00:00, 11.75it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 101.40it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [01:12<00:00, 11.74it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:06<00:00, 101.32it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [01:12<00:00, 11.72it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 99.93it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [01:12<00:00, 11.72it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 100.18it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [01:13<00:00, 11.36it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:06<00:00, 100.16it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [01:13<00:00, 11.64it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:06<00:00, 99.64it/s]
# Early Stop Intiallized
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:10<00:00, 82.54it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Accuracy: 2.3025976616701636
# ======================================================
# *** Output file ./results/exp1_2_L8_K256.json written

# %%
plot_exp_results('exp1_2_L2*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L2_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
plot_exp_results('exp1_2_L4*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L4_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
plot_exp_results('exp1_2_L8*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L8_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %% [markdown]
# ### Question 2
#
# Analyze your results from experiment 1.2. In particular, compare to the results of experiment 1.1. For a spesific value of L, how the preformance change with respect to K? Does we saw the same phenomena in 1.1 for a spresific value of K?

# %% [markdown]
# **ANSWER**:
# First, as seen in experiment 1.1, the L_8 isnt learning for the presented values of k, so the same phenomena happens for any presented value of K.
#
# For L_4 we can see that the best training results comes from K128 and K256.
# The best test results comes from K256, but the second best results comes from L32. In comparison to 1.1 the training accuracy is higher for the values K128 and K256, but the test accuracy is similiar for K128 and K256, and isnt much different with K32 and K64 in compirason to experiment 1.1
# The best Accuracy comes from K256.
# The perfomance doesn't change much for a specific value of K, but in this case, for better performance we will get the higher K.
#
# For L_2 we can see that best training results comes from K64 and K256.
# The best test results comes K256 and K64 (the differences are minimal).
# In this case, in comparison to experiment 1.1 we dont see much changes in the training accuracy results and the test accuracy results for the presented values of K.
# The perfomance doesnt change much in this case for a specific value of K.
# We can see that the same phenomena happens in compirason to experiment 1.1 for values of K=32,64,256 in the test results and training result, as for K=128 we got lower accuracy result in compirason to experiment 1.1 (for training and the test).

# %%
# %%shell
# jupyter nbconvert --to html "/content/drive/MyDrive/HomeWorks/HomeWork-DeepLearning/assignment2/CNN/CNNs_assignment.ipynb"
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/HomeWorks/HomeWork-DeepLearning/assignment2/CNN/CNNs_assignment.ipynb to html
# [NbConvertApp] Writing 1212354 bytes to /content/drive/MyDrive/HomeWorks/HomeWork-DeepLearning/assignment2/CNN/CNNs_assignment.html
